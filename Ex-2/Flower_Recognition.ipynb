# %% [markdown]
# <a href="https://colab.research.google.com/github/PrinceGupta1999/Flower-Recognition-Hackerearth/blob/master/Ex-2/Flower_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flower Recognition

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
from fastai.vision import *
from fastai.metrics import error_rate, accuracy

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 128
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# ## Looking at the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/HE_Challenge_data.zip'
# Out:
# Archive:  /content/drive/My Drive/HE_Challenge_data.zip
#   inflating: data/sample_submission.csv
#   inflating: data/test.csv
#    creating: data/test/
#   inflating: data/test/.DS_Store
#   inflating: data/test/18540.jpg
#   inflating: data/test/18541.jpg
#   inflating: data/test/18542.jpg
#   inflating: data/test/18543.jpg
#   inflating: data/test/18544.jpg
#   inflating: data/test/18545.jpg
#   inflating: data/test/18546.jpg
#   inflating: data/test/18547.jpg
#   inflating: data/test/18548.jpg
#   inflating: data/test/18549.jpg
#   inflating: data/test/18550.jpg
#   inflating: data/test/18551.jpg
#   inflating: data/test/18552.jpg
#   inflating: data/test/18553.jpg
#   inflating: data/test/18554.jpg
#   inflating: data/test/18555.jpg
#   inflating: data/test/18556.jpg
#   inflating: data/test/18557.jpg
#   inflating: data/test/18558.jpg
#   inflating: data/test/18559.jpg
#   inflating: data/test/18560.jpg
#   inflating: data/test/18561.jpg
#   inflating: data/test/18562.jpg
# ...

# %%
path = pathlib.Path('/content/data')
drive_path = pathlib.Path('/content/drive/My Drive/Flower_Recognition/Ex-1')

# %%
path.ls(), drive_path.ls()
# Out:
# ([PosixPath('/content/data/train.csv'),
#   PosixPath('/content/data/test'),
#   PosixPath('/content/data/sample_submission.csv'),
#   PosixPath('/content/data/train'),
#   PosixPath('/content/data/test.csv')],
#  [PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-1/data.pkl'),
#   PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-1/stage-1-50.pth'),
#   PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-1/tmp.pth'),
#   PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-1/stage-2-50.pth'),
#   PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-1/submission.csv')])

# %%
df_train = pd.read_csv(path/'train.csv')

# %%
df_train[:10]
# Out:
#    image_id  category
# 0         0        77
# 1         1        81
# 2         2        52
# 3         3        72
# 4         4        58
# 5         5         2
# 6         6        75
# 7         7        67
# 8         8        51
# 9         9        15

# %%
df_train['category'].value_counts()
# Out:
# 51     582
# 77     567
# 46     441
# 73     438
# 89     414
# 74     387
# 81     375
# 94     366
# 88     348
# 78     309
# 83     297
# 43     294
# 41     288
# 95     288
# 75     270
# 58     258
# 82     252
# 60     246
# 56     246
# 76     243
# 37     243
# 80     237
# 65     231
# 72     216
# 53     210
# 44     210
# 23     207
# 96     207
# 50     207
# 12     198
#       ...
# 64     117
# 61     114
# 19     111
# 15     111
# 49     111
# 100    111
# 13     111
# 14     108
# 102    108
# 93     105
# 9      105
# 33     105
# 32     102
# 6      102
# 10     102
# 35      99
# 67      96
# 24      96
# 39      93
# 79      93
# 25      93
# 26      93
# 16      93
# 34      90
# 3       90
# 21      90
# 7       90
# 1       90
# 27      90
# 45      90
# Name: category, Length: 102, dtype: int64

# %%
np.random.seed(2)

# %%
tfms = get_transforms()
data = (ImageList.from_df(df_train, path=path, folder='train', suffix='.jpg')
        #Where to find the data? -> in planet 'train' folder
        .split_by_rand_pct(0.4)
        #How to split in train/valid? -> by is_valid column
        .label_from_df()
        #How to label? -> use the second column of the csv file and split the tags by ' '
        .transform(tfms, size=224)
        #Data augmentation? -> use tfms with a size of 128
        .add_test_folder(test_folder='test')
        .databunch()
        .normalize(imagenet_stats))                          
        #Finally -> use the defaults for conversion to databunch

# %%
data.save(drive_path/'data.pkl')

# %%
data = load_data(path=drive_path, file='data.pkl', bs=bs//2)

# %%
data.train_ds
# Out:
# LabelList (11124 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# 72,75,67,15,77
# Path: /content/data

# %%
data.valid_ds
# Out:
# LabelList (7416 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# 72,50,78,91,39
# Path: /content/data

# %%
data.test_ds
# Out:
# LabelList (2009 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: EmptyLabelList
# ,,,,
# Path: /content/data

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
len(data.classes)
# Out:
# 102

# %%
counts = Counter(data.train_ds.y.items)

# %%
counts = [(len(data.train_ds) / counts[k]) for k in range(102)]

# %%
counts[:5]
# Out:
# [247.2, 144.46753246753246, 206.0, 130.87058823529412, 114.68041237113403]

# %%
class_weights = tensor(np.interp(counts, (min(counts), max(counts)), (0.5, 2.5)))

# %%
class_weights[:10]
# Out:
# tensor([2.5000, 1.5399, 2.1149, 1.4128, 1.2615, 1.8665, 1.9518, 1.0418, 1.6749,
#         1.8940], dtype=torch.float64)

# %%
loss_func = nn.NLLLoss(weight=class_weights)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.310717</td>
#       <td>0.415031</td>
#       <td>0.097087</td>
#       <td>06:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.357807</td>
#       <td>0.122734</td>
#       <td>0.029666</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.183354</td>
#       <td>0.062913</td>
#       <td>0.015642</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.129197</td>
#       <td>0.051251</td>
#       <td>0.012406</td>
#       <td>06:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ### Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)
# Out:
# <h4 id="_cl_int_plot_top_losses" class="doc_header"><code>_cl_int_plot_top_losses</code><a href="https://github.com/fastai/fastai/blob/master/fastai/vision/learner.py#L137" class="source_link" style="float:right">[source]</a><a class="source_link" data-toggle="collapse" data-target="#_cl_int_plot_top_losses-pytest" style="float:right; padding-right:10px">[test]</a></h4><blockquote><p><code>_cl_int_plot_top_losses</code>(<strong><code>k</code></strong>, <strong><code>largest</code></strong>=<strong><em><code>True</code></em></strong>, <strong><code>figsize</code></strong>=<strong><em><code>(12, 12)</code></em></strong>, <strong><code>heatmap</code></strong>:<code>bool</code>=<strong><em><code>None</code></em></strong>, <strong><code>heatmap_thresh</code></strong>:<code>int</code>=<strong><em><code>16</code></em></strong>, <strong><code>return_fig</code></strong>:<code>bool</code>=<strong><em><code>None</code></em></strong>) → <code>Optional</code>[<code>Figure</code>]</p>
# ...

# %%
# interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [(1, 51, 5),
#  (96, 97, 4),
#  (4, 88, 3),
#  (51, 95, 3),
#  (11, 95, 2),
#  (40, 97, 2),
#  (43, 89, 2),
#  (90, 4, 2),
#  (95, 96, 2),
#  (101, 51, 2)]

# %% [markdown]
# ### Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.204423</td>
#       <td>0.059804</td>
#       <td>0.013754</td>
#       <td>06:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
len(data.valid_ds), len(data.train_ds)
# Out:
# (3708, 14832)

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.099849</td>
#       <td>0.039379</td>
#       <td>0.010248</td>
#       <td>06:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.081031</td>
#       <td>0.026047</td>
#       <td>0.006472</td>
#       <td>06:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.060498</td>
#       <td>0.023892</td>
#       <td>0.006742</td>
#       <td>06:38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That's a pretty accurate model!

# %%
learn.save('stage-2')

# %%
preds_34, _ = learn.TTA(ds_type=DatasetType.Test)

# %%
preds_34.shape
# Out:
# torch.Size([2009, 102])

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
learn = cnn_learner(data, models.resnet50, metrics=[error_rate, accuracy], model_dir=drive_path)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:01<00:00, 59648276.49it/s]

# %%
learn.crit = loss_func
learn.model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-98d08ea33b8a> in <module>()
# ----> 1 learn.crit = loss_func
#       2 learn.model
#
# NameError: name 'loss_func' is not defined

# %%
learn.fit_one_cycle(4)

# %%
learn.save('stage-1-50')

# %% [markdown]
# ### Results

# %% [markdown]
# Let's see what results we have got.
#
# We will first see which were the categories that the model most confused with one another. We will try to see if what the model predicted was reasonable or not. In this case the mistakes look reasonable (none of the mistakes seems obviously naive). This is an indicator that our classifier is working correctly.
#
# Furthermore, when we plot the confusion matrix, we can see that the distribution is heavily skewed: the model makes the same mistakes over and over again but it rarely confuses other categories. This suggests that it just finds it difficult to distinguish some specific categories between each other; this is normal behaviour.

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
# interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [(96, 97, 8),
#  (3, 9, 3),
#  (84, 37, 3),
#  (88, 36, 3),
#  (99, 101, 3),
#  (1, 51, 2),
#  (4, 88, 2),
#  (5, 100, 2),
#  (11, 94, 2),
#  (40, 51, 2),
#  (43, 89, 2),
#  (65, 53, 2),
#  (68, 90, 2),
#  (72, 4, 2),
#  (72, 84, 2),
#  (83, 51, 2),
#  (90, 43, 2),
#  (90, 74, 2)]

# %% [markdown]
# ### Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.load('stage-1-50')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (11124 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# 72,75,67,15,77
# Path: /content/data;
#
# Valid: LabelList (7416 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# 72,50,78,91,39
# Path: /content/data;
#
# Test: LabelList (2009 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: EmptyLabelList
# ,,,,
# Path: /content/data, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# ...

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
len(data.valid_ds), len(data.train_ds)
# Out:
# (7416, 11124)

# %%
learn.unfreeze()
learn.fit_one_cycle(6, max_lr=slice(3e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.085139</td>
#       <td>0.053098</td>
#       <td>0.010922</td>
#       <td>0.989078</td>
#       <td>07:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.064476</td>
#       <td>0.036255</td>
#       <td>0.008225</td>
#       <td>0.991775</td>
#       <td>06:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.045180</td>
#       <td>0.028611</td>
#       <td>0.007012</td>
#       <td>0.992988</td>
#       <td>06:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.028480</td>
#       <td>0.025305</td>
#       <td>0.005394</td>
#       <td>0.994606</td>
#       <td>06:42</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %% [markdown]
# That's a pretty accurate model!

# %%
learn.save('stage-2-50')

# %%
learn.load('stage-2-50')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (11124 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# 72,75,67,15,77
# Path: /content/data;
#
# Valid: LabelList (7416 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# 72,50,78,91,39
# Path: /content/data;
#
# Test: LabelList (2009 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: EmptyLabelList
# ,,,,
# Path: /content/data, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# ...

# %%
learn.freeze()

# %% [markdown]
# ### Learn on same images with larger Size (and try more data augmentation as well)

# %%
np.random.seed(2)

# %%
tfms = get_transforms(max_rotate=25.0, max_zoom=1.3, max_lighting=0.3)
data = (ImageList.from_df(df_train, path=path, folder='train', suffix='.jpg')
        #Where to find the data? -> in planet 'train' folder
        .split_by_rand_pct(0.4)
        #How to split in train/valid? -> by is_valid column
        .label_from_df()
        #How to label? -> use the second column of the csv file and split the tags by ' '
        .transform(tfms, size=299)
        #Data augmentation? -> use tfms with a size of 128
        .add_test_folder(test_folder='test')
        .databunch()
        .normalize(imagenet_stats))                          
        #Finally -> use the defaults for conversion to databunch

# %%
path = pathlib.Path('/content/data')
drive_path = pathlib.Path('/content/drive/My Drive/Flower_Recognition/Ex-2')

# %%
drive_path.ls()
# Out:
# [PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-2/stage-3-50.pth'),
#  PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-2/data-299.pkl'),
#  PosixPath('/content/drive/My Drive/Flower_Recognition/Ex-2/tmp.pth')]

# %%
learn.model_dir = drive_path

# %%
data.save(drive_path/'data-299.pkl')

# %%
data = load_data(path=drive_path, file='data-299.pkl', bs=bs//2)

# %%
learn.data = data

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.168402</td>
#       <td>0.060142</td>
#       <td>0.015912</td>
#       <td>0.984088</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.092115</td>
#       <td>0.021207</td>
#       <td>0.005259</td>
#       <td>0.994741</td>
#       <td>04:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.041625</td>
#       <td>0.018652</td>
#       <td>0.004720</td>
#       <td>0.995281</td>
#       <td>04:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-3-50')

# %%
learn.load('stage-3-50')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (11124 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# 72,75,67,15,77
# Path: /content/data;
#
# Valid: LabelList (7416 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: CategoryList
# 72,50,78,91,39
# Path: /content/data;
#
# Test: LabelList (2009 items)
# x: ImageList
# Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299),Image (3, 299, 299)
# y: EmptyLabelList
# ,,,,
# Path: /content/data, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# ...

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6, 1e-5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.033259</td>
#       <td>0.016777</td>
#       <td>0.004180</td>
#       <td>0.995820</td>
#       <td>05:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.033357</td>
#       <td>0.016075</td>
#       <td>0.003910</td>
#       <td>0.996090</td>
#       <td>05:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.031179</td>
#       <td>0.016187</td>
#       <td>0.003776</td>
#       <td>0.996224</td>
#       <td>05:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-4-50')

# %% [markdown]
# # Finalizing Test Results

# %%
preds_50, _ = learn.TTA(ds_type=DatasetType.Test, beta=0.25)

# %%
preds_50.shape
# Out:
# torch.Size([2009, 102])

# %%
filenames = os.listdir(path/'test')

# %%
labels = []

# %%
preds = preds_50 #+ preds_34

# %%
images = [name.split('.')[0] for name in filenames if name.split('.')[1] == 'jpg']

# %%
images[:5]
# Out:
# ['18695', '19624', '20158', '20373', '20284']

# %%
for pred in preds:
  labels.append(int(np.argmax(pred)) + 1)
print(len(images) == len(labels))
# Out:
# True

# %%
submission = pd.DataFrame({
    'image_id': images,
    'category': labels
})
submission = submission.sort_values(by = ['image_id'], ascending = [True])
submission.to_csv(drive_path/'submission.csv',index=False)
